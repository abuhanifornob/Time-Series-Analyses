# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/data/appe_no_dates.csv')

# %%
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  142.90  144.75  142.90  144.18  19201712
# 1  143.02  143.50  142.41  142.73  24128782
# 2  143.69  144.79  142.72  144.09  21569557
# 3  144.88  145.30  143.10  143.50  14277848
# 4  144.45  144.96  143.78  144.02  23024107

# %%
df.shape
# Out:
# (26, 5)

# %%
Date=pd.date_range(start='3/01/2022',end='4/5/2022',freq="B")
Date
# Out:
# DatetimeIndex(['2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-07', '2022-03-08', '2022-03-09', '2022-03-10',
#                '2022-03-11', '2022-03-14', '2022-03-15', '2022-03-16',
#                '2022-03-17', '2022-03-18', '2022-03-21', '2022-03-22',
#                '2022-03-23', '2022-03-24', '2022-03-25', '2022-03-28',
#                '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01',
#                '2022-04-04', '2022-04-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index(Date,inplace=True)

# %%
df.head()
# Out:
#               Open    High     Low   Close    Volume
# 2022-03-01  142.90  144.75  142.90  144.18  19201712
# 2022-03-02  143.02  143.50  142.41  142.73  24128782
# 2022-03-03  143.69  144.79  142.72  144.09  21569557
# 2022-03-04  144.88  145.30  143.10  143.50  14277848
# 2022-03-07  144.45  144.96  143.78  144.02  23024107

# %%
daly_index=pd.date_range(start='3/01/2022',end='3/30/2022',freq='D')
daly_index
# Out:
# DatetimeIndex(['2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08',
#                '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-12',
#                '2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16',
#                '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20',
#                '2022-03-21', '2022-03-22', '2022-03-23', '2022-03-24',
#                '2022-03-25', '2022-03-26', '2022-03-27', '2022-03-28',
#                '2022-03-29', '2022-03-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
wekly_index=pd.date_range(start='3/01/2022',end='3/30/2022',freq='W')
wekly_index
# Out:
# DatetimeIndex(['2022-03-06', '2022-03-13', '2022-03-20', '2022-03-27'], dtype='datetime64[ns]', freq='W-SUN')

# %% [markdown]
# **Finding missing dates from datetimeindex**

# %%
daly_index.difference(df.index)
# Out:
# DatetimeIndex(['2022-03-05', '2022-03-06', '2022-03-12', '2022-03-13',
#                '2022-03-19', '2022-03-20', '2022-03-26', '2022-03-27'],
#               dtype='datetime64[ns]', freq=None)

# %%
wekly_index.difference(df.index)
# Out:
# DatetimeIndex(['2022-03-06', '2022-03-13', '2022-03-20', '2022-03-27'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# **Benefits of having DatetimeIndex**

# %%
df.Close.plot()

# %%
df.High.plot()

# %%
df['2022-03-01':'2022-03-10']
# Out:
#               Open    High     Low   Close    Volume
# 2022-03-01  142.90  144.75  142.90  144.18  19201712
# 2022-03-02  143.02  143.50  142.41  142.73  24128782
# 2022-03-03  143.69  144.79  142.72  144.09  21569557
# 2022-03-04  144.88  145.30  143.10  143.50  14277848
# 2022-03-07  144.45  144.96  143.78  144.02  23024107
# 2022-03-08  144.71  145.13  142.28  143.68  31499368
# 2022-03-09  144.49  146.11  143.16  145.83  22082432
# 2022-03-10  145.01  146.16  143.62  143.73  24761891

# %%
df.Close['2022-03-01':'2022-03-10'].mean()
# Out:
# 143.97

# %%
df.head()
# Out:
#               Open    High     Low   Close    Volume
# 2022-03-01  142.90  144.75  142.90  144.18  19201712
# 2022-03-02  143.02  143.50  142.41  142.73  24128782
# 2022-03-03  143.69  144.79  142.72  144.09  21569557
# 2022-03-04  144.88  145.30  143.10  143.50  14277848
# 2022-03-07  144.45  144.96  143.78  144.02  23024107

# %% [markdown]
# 2022-04-04 22:00:00  153.58  155.45  152.89  155.45  27770715
# 2022-04-04 23:00:00  153.58  155.45  152.89  155.45  27770715
# 2022-04-05 00:00:00  153.17  153.33  152.22  153.18  16404088
#
# [841 rows x 5 columns]

# %% [markdown]
# **generating DatetimeIndex with periods argument**

# %%
rng=pd.date_range(start='03/01/2022',periods=36,freq='D')
rng
# Out:
# DatetimeIndex(['2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08',
#                '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-12',
#                '2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16',
#                '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20',
#                '2022-03-21', '2022-03-22', '2022-03-23', '2022-03-24',
#                '2022-03-25', '2022-03-26', '2022-03-27', '2022-03-28',
#                '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01',
#                '2022-04-02', '2022-04-03', '2022-04-04', '2022-04-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng=pd.date_range(start='03/01/2022',periods=72,freq='D')
rng
# Out:
# DatetimeIndex(['2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08',
#                '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-12',
#                '2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16',
#                '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20',
#                '2022-03-21', '2022-03-22', '2022-03-23', '2022-03-24',
#                '2022-03-25', '2022-03-26', '2022-03-27', '2022-03-28',
#                '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01',
#                '2022-04-02', '2022-04-03', '2022-04-04', '2022-04-05',
#                '2022-04-06', '2022-04-07', '2022-04-08', '2022-04-09',
#                '2022-04-10', '2022-04-11', '2022-04-12', '2022-04-13',
#                '2022-04-14', '2022-04-15', '2022-04-16', '2022-04-17',
#                '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21',
# ...

# %%
rng=pd.date_range(start='03/01/2022',periods=30,freq='W')
rng
# Out:
# DatetimeIndex(['2022-03-06', '2022-03-13', '2022-03-20', '2022-03-27',
#                '2022-04-03', '2022-04-10', '2022-04-17', '2022-04-24',
#                '2022-05-01', '2022-05-08', '2022-05-15', '2022-05-22',
#                '2022-05-29', '2022-06-05', '2022-06-12', '2022-06-19',
#                '2022-06-26', '2022-07-03', '2022-07-10', '2022-07-17',
#                '2022-07-24', '2022-07-31', '2022-08-07', '2022-08-14',
#                '2022-08-21', '2022-08-28', '2022-09-04', '2022-09-11',
#                '2022-09-18', '2022-09-25'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
tf=pd.Series(np.random.randint(1,10,len(rng)),index=rng)
tf
# Out:
# 2022-03-06    7
# 2022-03-13    9
# 2022-03-20    2
# 2022-03-27    2
# 2022-04-03    8
# 2022-04-10    5
# 2022-04-17    8
# 2022-04-24    4
# 2022-05-01    7
# 2022-05-08    9
# 2022-05-15    8
# 2022-05-22    6
# 2022-05-29    8
# 2022-06-05    4
# 2022-06-12    5
# 2022-06-19    9
# 2022-06-26    4
# 2022-07-03    6
# 2022-07-10    9
# 2022-07-17    8
# 2022-07-24    5
# 2022-07-31    8
# 2022-08-07    7
# 2022-08-14    3
# 2022-08-21    1
# 2022-08-28    3
# 2022-09-04    6
# 2022-09-11    2
# 2022-09-18    2
# 2022-09-25    4
# Freq: W-SUN, dtype: int64

# %% [markdown]
# **Custom frequency ranges**

# %%
import datetime
weekmask = "Fri"
holidays = [datetime.datetime(2022, 3, 19), datetime.datetime(2022, 3, 26)]
pd.bdate_range(start='03/01/2022', end='3/30/2022', freq="C",weekmask = "Fri")
# Out:
# DatetimeIndex(['2022-03-04', '2022-03-11', '2022-03-18', '2022-03-25'], dtype='datetime64[ns]', freq='C')

# %%
pd.bdate_range(start='03/01/2022', end='3/30/2022', freq="CBMS",weekmask = "Fri")
# Out:
# DatetimeIndex(['2022-03-04'], dtype='datetime64[ns]', freq='CBMS')
